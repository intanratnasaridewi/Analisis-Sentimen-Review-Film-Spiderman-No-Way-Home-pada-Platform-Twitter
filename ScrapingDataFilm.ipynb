# %%
import tweepy as tw
API_KEY = 'aSNxhYbRGSe6DPjaZceBEOU5x'
SECRET_KEY = '1TbzgQCXLikWZ7mEa92aKgwPx8p6Mvt8lKGCsDPjzGzMUwRbmf'
ACCESS_TOKEN = '1514220686465978368-2jkZ5LERhhM6I0lvjwZetLteoig3MR'
SECRET_TOKEN = 'v8uSjVbKrzVzVVRoEkQ7rk8JIIGwalyjxzQ8jegdcLbYV'

# %%
auth = tw.OAuthHandler(API_KEY, SECRET_KEY)
auth.set_access_token(ACCESS_TOKEN, SECRET_TOKEN)
api = tw.API(auth, wait_on_rate_limit=True)

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

tweets_list2 = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('spiderman no way home since:2019-06-01 until:2022-04-04').get_items()):
    if i>10000:
         break
    tweets_list2.append([ tweet.id])
    
tweets_df2 = pd.DataFrame(tweets_list2, columns=['Tweet Id'])
tweets_df2.size
# Out:
# [[1510768431087431795],
#  [1510766572872294409],
#  [1510764324872093699],
#  [1510763893106171906],
#  [1510763092791238662],
#  [1510760838801596422],
#  [1510760432537116674],
#  [1510760195080740870],
#  [1510758617934225416],
#  [1510756823539855360],
#  [1510756107555377159],
#  [1510755898016387077],
#  [1510755881784336386],
#  [1510755668898336772],
#  [1510754854892818432],
#  [1510754498112901126],
#  [1510753450577080324],
#  [1510752025868447755],
#  [1510751887372566530],
#  [1510746491983437824],
#  [1510745913672753159],
#  [1510742331313557505],
#  [1510741890567704576],
#  [1510741329998974978],
#  [1510739049719336963],
#  [1510738645543755779],
#  [1510735661996728323],
#  [1510735605776281600],
#  [1510735549962801154],
#  [1510734781889323016],
#  [1510733872023101448],
#  [1510732670392668167],
#  [1510732474892136456],
#  [1510731613793296385],
#  [1510731136359616513],
#  [1510730489144954888],
#  [1510730195585675266],
#  [1510730058251526152],
# ...

# %%
tweets_df2
# Out:
#                   Tweet Id
# 0      1510768431087431795
# 1      1510766572872294409
# 2      1510764324872093699
# 3      1510763893106171906
# 4      1510763092791238662
# ...                    ...
# 9996   1503161017681031178
# 9997   1503159437132935172
# 9998   1503159369713733632
# 9999   1503159263228678144
# 10000  1503158996433309699
#
# [10001 rows x 1 columns]

# %%
import pymongo
from pymongo import MongoClient
# cluster = MongoClient("mongodb+srv://intanratnasaridewi:intan271001>@cluster0.xzz8y.mongodb.net/dbFilm?retryWrites=true&w=majority")
client = pymongo.MongoClient("mongodb+srv://intanratna:intan271001@datafilm.xzz8y.mongodb.net/dbFilm?retryWrites=true&w=majority")
db = client.dbFilm
collection = db.datafilm
collectioncleansing = db.datafilmcleansing
import pandas as pd
import re
counter = 0

# %%
for id in tweets_df2['Tweet Id']:
    tweet = api.get_status(id)
#     print(tweet)
    print('Tweet Downloaded: ', counter)
    collection.insert_one( tweet._json) 

#     print()
    counter+=1
# Out:
# Tweet Downloaded:  0
# Tweet Downloaded:  1
# Tweet Downloaded:  2
# Tweet Downloaded:  3
# Tweet Downloaded:  4
# Tweet Downloaded:  5
# Tweet Downloaded:  6
# Tweet Downloaded:  7
# Tweet Downloaded:  8
# Tweet Downloaded:  9
# Tweet Downloaded:  10
# Tweet Downloaded:  11
# Tweet Downloaded:  12
# Tweet Downloaded:  13
# Tweet Downloaded:  14
# Tweet Downloaded:  15
# Tweet Downloaded:  16
# Tweet Downloaded:  17
# Tweet Downloaded:  18
# Tweet Downloaded:  19
# Tweet Downloaded:  20
# Tweet Downloaded:  21
# Tweet Downloaded:  22
# Tweet Downloaded:  23
# Tweet Downloaded:  24
# Tweet Downloaded:  25
# Tweet Downloaded:  26
# Tweet Downloaded:  27
# Tweet Downloaded:  28
# Tweet Downloaded:  29
# Tweet Downloaded:  30
# Tweet Downloaded:  31
# Tweet Downloaded:  32
# Tweet Downloaded:  33
# Tweet Downloaded:  34
# Tweet Downloaded:  35
# Tweet Downloaded:  36
# Tweet Downloaded:  37
# Tweet Downloaded:  38
# Tweet Downloaded:  39
# Tweet Downloaded:  40
# Tweet Downloaded:  41
# ...

# %%
# for x in
data=[]
data=collection.find({},{ "_id": 0, "text": 1, "created_at":1})
tweets_h = pd.DataFrame(data,columns=['text', 'created_at'] )
data
#     print(x)
tweets_h
# Out:
#                                                    text  \
# 0     NO PUEDO CREER LO QUE FUE EL ÚLTIMO CAPITULO D...
# 1              los grammys son mi spiderman no way home
# 2     Y a esto se le suma que Spiderman a traído más...
# 3     No entiendo porque a huevo quieren poner a And...
# 4     @BlackBooken @ThonyMagio17 @StripMarvel En rea...
# ...                                                 ...
# 1014  y... meter un par de referencias en las post-c...
# 1015             spiderman no way home internete düşmüş
# 1016  @AFCTQ Bonjour je tente ma chance avec grand p...
# 1017  💥 SAVE THE DATE 💥\n\nJoin us TUESDAY, 4/12  9p...
# 1018  Are we ready for this discussion?  Spiderman n...
#
#                           created_at
# 0     Sun Apr 03 23:57:17 +0000 2022
# 1     Sun Apr 03 23:49:54 +0000 2022
# 2     Sun Apr 03 23:40:58 +0000 2022
# 3     Sun Apr 03 23:39:15 +0000 2022
# 4     Sun Apr 03 23:36:04 +0000 2022
# ...                              ...
# ...

# %%
import re
import string
import nltk
nltk.download('punkt')

def casefolding(review):
    review = str(review).lower()
    return review

tweets_h['text']=tweets_h['text'].apply(casefolding)


def tokenize(review):
    token = nltk.word_tokenize(review)
    return token
 
tweets_h['text']=tweets_h['text'].apply(tokenize)

def filtering(review):
    # Remove link web
    review = re.sub(r'http\S+', '', str(review))
    # Remove @username
    review = re.sub('@[^\s]+', '', str(review))
    # Remove #tagger
    review = re.sub(r'#([^\s]+)', '', str(review))
    # Remove angka termasuk angka yang berada dalam string
    # Remove non ASCII chars
    review = re.sub(r'[^\x00-\x7f]', r'', str(review))
    review = re.sub(r'(\\u[0-9A-Fa-f]+)', r'', str(review))
    review = re.sub(r"[^A-Za-z0-9^,!.\/'+-=]", " ", str(review))
    review = re.sub(r'\\u\w\w\w\w', '', str(review))
    # Remove simbol, angka dan karakter aneh
    review = re.sub(r"[.,:;+!\-_<^/=?\"'\(\)\d\*]", " ", str(review))
    return review

tweets_h['text']=tweets_h['text'].apply(filtering)
 
tweets_h
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\intan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#                                                    text  \
# 0       no    puedo    creer    lo    que    fue    ...
# 1       los    grammys    son    mi    spiderman    ...
# 2       y    a    esto    se    le    suma    que   ...
# 3       no    entiendo    porque    a    huevo    qu...
# 4       blackbooken    thonymagio    stripmarvel    ...
# ...                                                 ...
# 1014    y    meter    un    par    de    referencias...
# 1015    spiderman    no    way    home    internete ...
# 1016    afctq    bonjour    je    tente    ma    cha...
# 1017    save    the    date    join    us    tuesday...
# 1018    are    we    ready    for    this    discuss...
#
#                           created_at
# 0     Sun Apr 03 23:57:17 +0000 2022
# 1     Sun Apr 03 23:49:54 +0000 2022
# ...

# %%
 import json

records = json.loads(tweets_h.T.to_json()).values()
db.datafilmcleansing.insert_many(records)

# %%
import time
import pymongo
from googletrans import Translator

client = pymongo.MongoClient("mongodb+srv://intanratna:intan271001@datafilm.xzz8y.mongodb.net/dbFilm?retryWrites=true&w=majority")
db = client.dbFilm
collection = db.datafilmcleansing
db.coll.find()
collectionTranslated = db.translatedatafilm
text = collection.find({}, {'_id': 0, 'text': 1, 'created_at':1})
translator = Translator()
for i in text:
    try:
        translation = translator.translate(i['text'], dest='en')
        words = translation.text
        document = {"text": words, "created_at":i['created_at']}
        collectionTranslated.insert_one(document)
        print(translation.text)
        time.sleep(0.5)
    except Exception as e:
        print("Erro {}".format(e))
# Out:
# I can't believe what was the last chapter of Peaky Blinders Fnlksdasd I am like when I left the cinema after t co or c xewgut
# los grammys son min spider man no way home
# And to this it is added that Spiderman to trado more bad times to Garfield that any other project does not go home no t co iqcg mwzq
# I don't understand why Egg wants to put Andrew Garfield with more relevance that he has in no way home is t t co vbwyrkxub
# BlackBooken Thonymagio stripmarvel actually yes and not since in the post -wa t chords scene no wa t co j s c wcpn
# why    did    watching    spiderman    no    way    home    make    me    cry    so    damn    much
# altsoggypickles    i    always    appreciated    him    i    loved    the    first    amazing    spiderman    movie    the    second    one    has    its    proble    t    co    x    rzuxgh
# ...

# %%
from nltk.stem.snowball import SnowballStemmer

# Use English stemmer.
stemmer = SnowballStemmer("english")
data=[]
client = pymongo.MongoClient("mongodb+srv://intanratna:intan271001@datafilm.xzz8y.mongodb.net/dbFilm?retryWrites=true&w=majority")
db = client.dbFilm
collectionTranslated = db.translatedatafilm
data=collectionTranslated.find({}, {'_id': 0, 'text': 1, 'created_at':1})
tweets = pd.DataFrame(data,columns=['text', 'Label', 'created_at'])

def filtering(text):
     text = re.sub(r'@[a-zA-Z0-9]+', '', text)
     text = re.sub(r',', '', text)
     text = re.sub(r'#', '', text)
     text = re.sub(r'!', '', text)
     text = re.sub(r'&', '', text)
     text = re.sub(r"b'", '', text)
     text = re.sub(r"\'", '', text)
     text = re.sub(r"_.*", '', text)
     text = re.sub(r"wk.*wk", '', text)
     text = re.sub('\[.*?\]', '', text)
     text = re.sub(r'\[a-zA-Z0-9+', '', text)
     text = re.sub(r'\w*\d+\w*', '', text)
     text = re.sub(r'\\.*\\', "", text)
     text = re.sub("https*\S+", " ", text)
     text = re.sub('\s{2,}', " ", text)
     text = text.lower()
     text = text.encode('ascii', 'ignore').decode()
     return text


tweets['text']=tweets['text'].apply(filtering)
 
tweets['text'] =tweets['text'].apply(stemmer.stem)



tweets.to_csv('data.csv')

# %%
import pandas as pd
# train Data

trainData = pd.read_csv("https://raw.githubusercontent.com/Vasistareddy/sentiment_analysis/master/data/train.csv")
testData=pd.read_csv("https://raw.githubusercontent.com/Vasistareddy/sentiment_analysis/master/data/test.csv")
# testData=pd.read_csv('data.csv')

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
# Create feature vectors
vectorizer = TfidfVectorizer(min_df = 5,
                             max_df = 0.8,
                             sublinear_tf = True,
                             use_idf = True)
train_vectors = vectorizer.fit_transform(trainData['Content'])
test_vectors = vectorizer.transform(testData['Content'])

# %%
import time
from sklearn import svm
from sklearn.metrics import classification_report
# Perform classification with SVM, kernel=linear
classifier_linear = svm.SVC(kernel='linear')
t0 = time.time()
classifier_linear.fit(train_vectors, trainData['Label'])
t1 = time.time()
prediction_linear = classifier_linear.predict(test_vectors)
t2 = time.time()
time_linear_train = t1-t0
time_linear_predict = t2-t1
# results
print("Training time: %fs; Prediction time: %fs" % (time_linear_train, time_linear_predict))
report = classification_report(testData['Label'], prediction_linear, output_dict=True)
print('positive: ', report['pos'])
print('negative: ', report['neg'])
# Out:
# Training time: 18.743221s; Prediction time: 1.802339s
# positive:  {'precision': 0.9191919191919192, 'recall': 0.91, 'f1-score': 0.9145728643216081, 'support': 100}
# negative:  {'precision': 0.9108910891089109, 'recall': 0.92, 'f1-score': 0.9154228855721394, 'support': 100}

# %%
testData=pd.read_csv('data.csv')

# client = pymongo.MongoClient("mongodb+srv://intanratna:intan271001@datafilm.xzz8y.mongodb.net/dbFilm?retryWrites=true&w=majority")
# db = client.dbFilm
# collection = db.translatedatafilm
# text = collection.find({}, {'_id': 0, 'text': 1, 'created_at':1})


# # Define a dictionary containing Students data
# data = {'Name': ['Jai', 'Princi', 'Gaurav', 'Anuj'],
#         'Height': [5.1, 6.2, 5.1, 5.2],
#         'Qualification': ['Msc', 'MA', 'Msc', 'Msc']}
  
# # Convert the dictionary into DataFrame
# df = pd.DataFrame(data)


created_at=testData['created_at']
review =testData['text']
review_vector = vectorizer.transform(review) # vectorizing
hasil=classifier_linear.predict(review_vector)


data={'text': review, 'Label': hasil, 'created_at':created_at}
tweetsbaru = pd.DataFrame(data).astype('string')
tweetsbaru.to_csv('datasentimen.csv')
# tweetsbaru = pd.DataFrame(review, hasil,  columns=['Label'], created_at).astype('string')
tweetsbaru.head()
# Out:
#                                                 text Label created_at
# 0  i cant believe what was the last chapter of pe...   neg       <NA>
# 1          los grammys son min spider man no way hom   pos       <NA>
# 2  and to this it is added that spiderman to trad...   neg       <NA>
# 3  i dont understand why egg wants to put andrew ...   neg       <NA>
# 4  blackbooken thonymagio stripmarvel actually ye...   neg       <NA>

# %%
testData=pd.read_csv('data.csv')
testData
# Out:
#      Unnamed: 0                                               text  Label  \
# 0             0  i cant believe what was the last chapter of pe...    NaN
# 1             1          los grammys son min spider man no way hom    NaN
# 2             2  and to this it is added that spiderman to trad...    NaN
# 3             3  i dont understand why egg wants to put andrew ...    NaN
# 4             4  blackbooken thonymagio stripmarvel actually ye...    NaN
# ..          ...                                                ...    ...
# 131         131  spiderman no way home shows a way that does no...    NaN
# 132         132  someone call tonight to see spidermans movie n...    NaN
# 133         133  artes de andy fairhurst de spiderman no way ho...    NaN
# 134         134  save the date join us tuesday pm to pm et pm p...    NaN
# 135         135  check out funko pop molten man vinyl bobble he...    NaN
#
#                          created_at
# 0                               NaN
# ...
